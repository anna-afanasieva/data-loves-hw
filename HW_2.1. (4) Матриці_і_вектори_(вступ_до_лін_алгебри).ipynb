# %% [markdown]
# ### Завдання 1: Створення матриць та векторів
# 1. Створіть `numpy` вектор `vector` розмірністю 10 з випадковими дійсними значеннями в діапазоні від 0 до 1. Можна скористатись двома альтернативними варіантами:
#   1. Генерація випадкових чисел з модулем [`random.uniform`](https://docs.python.org/3/library/random.html).
#   2. Створення вектора з допомогою метода `numpy` [np.random.rand](https://numpy.org/doc/stable/reference/random/generated/numpy.random.rand.html)
#
# 2. Створіть матрицю `matrix` типу `numpy.array` розмірності 3x3 з наступними значеннями
#
#   $$
#   matrix = \begin{bmatrix}
#   11 & 14 & 17 \\
#   20 & 23 & 26 \\
#   29 & 32 & 35
#   \end{bmatrix}
#   $$
#
#   будь-яким відомими Вам способом.
#
# Виведіть на екран вектор і матрицю, а також їх розміри.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
vector = np.random.rand(10)

vector
# Out:
# array([0.97231149, 0.31880911, 0.07554458, 0.00227555, 0.30787511,
#        0.38971278, 0.19816779, 0.45170217, 0.97653257, 0.07595457])

# %%
vector.shape
# Out:
# (10,)

# %%
B = np.array([[11, 14, 17],
              [20, 23, 26],
              [29, 32, 35]])

# %%
print("Матриця B:")
print(B)
# Out:
# Матриця B:
# [[11 14 17]
#  [20 23 26]
#  [29 32 35]]

# %%
B.shape
# Out:
# (3, 3)

# %% [markdown]
# ### Завдання 2: Операції над векторами та матрицями
# Виконайте кожну з зазначених операцій над зазначеними оʼєктами і виведіть результат на екран:
# 1. Додайте до кожного значення вектора `vector` число 10 і округліть кожне значення до 2 знаків після коми без використання циклів.
# 2. Помножте кожен елемент матриці з першого завдання на 2 без використання циклів.
# 3. Створіть новий вектор, який містить квадрат кожного `vector` без циклів.

# %%
# Додайте до кожного значення вектора vector число 10 і округліть кожне значення до 2 знаків після коми без використання циклів.
A1 = vector +10
A1
# Out:
# array([10.97231149, 10.31880911, 10.07554458, 10.00227555, 10.30787511,
#        10.38971278, 10.19816779, 10.45170217, 10.97653257, 10.07595457])

# %%
A2 = np.round(A1, 2)
A2
# Out:
# array([10.97, 10.32, 10.08, 10.  , 10.31, 10.39, 10.2 , 10.45, 10.98,
#        10.08])

# %%
# Помножте кожен елемент матриці з першого завдання на 2 без використання циклів.

B2 = B * 2
B2
# Out:
# array([[22, 28, 34],
#        [40, 46, 52],
#        [58, 64, 70]])

# %%
# Створіть новий вектор, який містить квадрат кожного vector без циклів.
vector_squared = vector ** 2
vector_squared
# Out:
# array([9.45389627e-01, 1.01639251e-01, 5.70698319e-03, 5.17813626e-06,
#        9.47870863e-02, 1.51876049e-01, 3.92704711e-02, 2.04034850e-01,
#        9.53615859e-01, 5.76909645e-03])

# %% [markdown]
# ### Завдання 3: Множення матриць
# 1. Задані дві матриці `A` і `B`розмірностями 3x2 та 2х3. Виконайте їхнє множення, щоб отримати матрицю 2x2. Виведіть результуючу матрицю `result_matrix` на екран.
#
# 2. Заданий вектор `C` розмірністю 2х1. Подумайте спочатку, яку розмірність Ви отрмаєте, коли домножите `result_matrix` на вектор `C` і який результат буде. А потім виконайте множення і виведіть результат на екран.
#
# 3. Задана матриця `D` розмірністю 2х2. Подумайте спочатку, яку розмірність Ви отрмаєте, коли домножите `result_matrix` на матрицю `D` і який результат буде. А потім виконайте множення і виведіть результат на екран.

# %%
A = np.array(
    [[0.18, 0.53],
     [0.75, 0.47],
     [0.35, 0.21]])

B = np.array(
    [[0.17, 0.58, 0.75],
     [0.38, 0.11, 0.15]])

C = np.array([[0], [1]])

D = np.array([[0,1], [1,0]])

display(A, B, C, D)
# Out:
# array([[0.18, 0.53],
#        [0.75, 0.47],
#        [0.35, 0.21]])
# array([[0.17, 0.58, 0.75],
#        [0.38, 0.11, 0.15]])
# array([[0],
#        [1]])
# array([[0, 1],
#        [1, 0]])

# %% [markdown]
# 1. Задані дві матриці A і Bрозмірностями 3x2 та 2х3. Виконайте їхнє множення, щоб отримати матрицю 2x2. Виведіть результуючу матрицю result_matrix на екран.

# %%
A = np.array(
    [[0.18, 0.53],
     [0.75, 0.47],
     [0.35, 0.21]]
)

# %%
A.shape
# Out:
# (3, 2)

# %%
B = np.array(
    [[0.17, 0.58, 0.75],
     [0.38, 0.11, 0.15]]
)

# %%
B.shape
# Out:
# (2, 3)

# %%
result_matrix = np.dot(B, A)
result_matrix
# Out:
# array([[0.7281, 0.5202],
#        [0.2034, 0.2846]])

# %%
result_matrix.shape
# Out:
# (2, 2)

# %% [markdown]
# 2. Заданий вектор C розмірністю 2х1. Подумайте спочатку, яку розмірність Ви отрмаєте, коли домножите result_matrix на вектор C і який результат буде. А потім виконайте множення і виведіть результат на екран.

# %%
C.shape
# Out:
# (2, 1)

# %%
result_matrix.shape
# Out:
# (2, 2)

# %%
result_vector = np.dot(result_matrix, C)

result_vector
# Out:
# array([[0.5202],
#        [0.2846]])

# %%
result_vector.shape
# Out:
# (2, 1)

# %% [markdown]
# 3. Задана матриця D розмірністю 2х2. Подумайте спочатку, яку розмірність Ви отрмаєте, коли домножите result_matrix на матрицю D і який результат буде. А потім виконайте множення і виведіть результат на екран.

# %%
D.shape
# Out:
# (2, 2)

# %%
D
# Out:
# array([[0, 1],
#        [1, 0]])

# %%
result_vector2 = np.dot(result_matrix, D)

result_vector2
# Out:
# array([[0.5202, 0.7281],
#        [0.2846, 0.2034]])

# %% [markdown]
# ### Завдання 4: Транспонування матриць
# 1. Транспонуйте `result_matrix`.
# 2. Зробіть транспонування вектора `vector` і виведіть форму нової структури. Чи бачите ви зміну?
# 3. Використайте операцію `numpy.expand_dims` над вектором `vector` з аргументом axis=1. Запишіть отриманий результат в змінну `column_vector` і виведіть на екран. Порівняйте з `vector`.
# 4. Зробіть транспонування `column_vector`, виведіть результат на екран разом з розмірностями отриманої структури.

# %% [markdown]
# 1. Транспонуйте result_matrix.

# %%
result_matrix
# Out:
# array([[0.7281, 0.5202],
#        [0.2034, 0.2846]])

# %%
result_matrix_T = result_matrix.T

result_matrix_T
# Out:
# array([[0.7281, 0.2034],
#        [0.5202, 0.2846]])

# %%
result_matrix_T.shape
# Out:
# (2, 2)

# %% [markdown]
# 2. Зробіть транспонування вектора vector і виведіть форму нової структури. Чи бачите ви зміну?

# %%
vector
# Out:
# array([0.97231149, 0.31880911, 0.07554458, 0.00227555, 0.30787511,
#        0.38971278, 0.19816779, 0.45170217, 0.97653257, 0.07595457])

# %%
vector_T = vector.T

vector_T
# Out:
# array([0.97231149, 0.31880911, 0.07554458, 0.00227555, 0.30787511,
#        0.38971278, 0.19816779, 0.45170217, 0.97653257, 0.07595457])

# %%
vector.shape, vector_T.shape
# Out:
# ((10,), (10,))

# %% [markdown]
# Ні, змін немає, бо vector є одновимірним масивом з формою (10,).

# %% [markdown]
# 3. Використайте операцію numpy.expand_dims над вектором vector з аргументом axis=1. Запишіть отриманий результат в змінну column_vector і виведіть на екран. Порівняйте з vector.

# %%
column_vector = np.expand_dims(vector, axis=1)

column_vector
# Out:
# array([[0.97231149],
#        [0.31880911],
#        [0.07554458],
#        [0.00227555],
#        [0.30787511],
#        [0.38971278],
#        [0.19816779],
#        [0.45170217],
#        [0.97653257],
#        [0.07595457]])

# %%
vector.shape, column_vector.shape
# Out:
# ((10,), (10, 1))

# %% [markdown]
# Після використання np.expand_dims(vector, axis=1) вектор став двовимірною структурою з формою (10, 1). На відміну від vector, який має форму (10,), column_vector виглядає як вектор-стовпчик.

# %% [markdown]
# 4. Зробіть транспонування column_vector, виведіть результат на екран разом з розмірностями отриманої структури.

# %%
column_vector_T = column_vector.T

print("Транспонований column_vector:")
print(column_vector_T)

print("Розмірність:")
print(column_vector_T.shape)
# Out:
# Транспонований column_vector:
# [[0.97231149 0.31880911 0.07554458 0.00227555 0.30787511 0.38971278
#   0.19816779 0.45170217 0.97653257 0.07595457]]
# Розмірність:
# (1, 10)
